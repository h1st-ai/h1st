# %%
# %load_ext autoreload
# %autoreload 2

# %%
from oracle_w_fuzzy import load_data
import pandas as pd

# %%
from h1st.model.predictive_model import PredictiveModel
class RuleModel(PredictiveModel):
    # 98 percentile
    daily_thresholds = {
        "volt": 188.83,  # >
        "rotate": 373.05,  # <
        "vibration": 49.38,  # >
    }

    def predict_pointwise(self, input_data):
        daily_average = np.average(
            input_data.reshape((-1, 4)), axis=0
        )
        volt_val = daily_average[0]
        rotate_val = daily_average[1]
        vibration_val = daily_average[3]

        pred = {"comp1": 0, "comp2": 0, "comp4": 0}
        pred['comp1'] = 1 if volt_val > self.daily_thresholds["volt"] else 0
        pred['comp2'] = 1 if rotate_val < self.daily_thresholds["rotate"] else 0
        pred['comp4'] = 1 if vibration_val > self.daily_thresholds["vibration"] else 0
        return pred

    def predict(self, input_data):
        df = input_data['x']
        return {'predictions': pd.DataFrame(
            map(self.predict_pointwise, df.values), 
        )}

# %%
import numpy as np
from h1st.model.fuzzy import (
    FuzzyVariables,
    FuzzyMembership as fm,
    FuzzyRules,
    FuzzyModel,
    FuzzyModeler
)

def get_meta_data(data):
    res = {}
    for k, v in dict(data.describe().loc['max']).items():
        res[k] = {'max': v}
    for k, v in dict(data.describe().loc['min']).items():
        res[k].update({'min': v})    
    return res

def create_fuzzy_model(data):
    meta_data = get_meta_data(data) # df_model3_daily
    fuzzy_vars = FuzzyVariables()
    fuzzy_vars.add(
        var_name='volt',
        var_type='antecedent',
        var_range=np.arange(
            meta_data['volt']['min'], 
            meta_data['volt']['max'], 
            0.1
        ),
        membership_funcs=[('high', fm.SIGMOID, [182, 0.25]),
                        ('low', fm.SIGMOID, [182, -0.25])]
    )
    fuzzy_vars.add(
        var_name='rotate',
        var_type='antecedent',
        var_range=np.arange(
            meta_data['rotate']['min'], 
            meta_data['rotate']['max'], 
            0.1
        ),
        membership_funcs=[('high', fm.SIGMOID, [400, 0.06]),
                        ('low', fm.SIGMOID, [400, -0.15])]
    )
    fuzzy_vars.add(
        var_name='vibration',
        var_type='antecedent',
        var_range=np.arange(
            meta_data['vibration']['min'], 
            meta_data['vibration']['max'], 
            0.1
        ),
        membership_funcs=[('high', fm.SIGMOID, [49, 0.5]),
                        ('low', fm.SIGMOID, [49, -0.5])]
    )
    fuzzy_vars.add(
        var_name='comp1',
        var_type='consequent',
        var_range=np.arange(0, 1+1e-5, 0.1),
        membership_funcs=[('false', fm.GAUSSIAN, [0, 0.4]),
                        ('true', fm.GAUSSIAN, [1, 0.4])]
    )
    fuzzy_vars.add(
        var_name='comp2',
        var_type='consequent',
        var_range=np.arange(0, 1+1e-5, 0.1),
        membership_funcs=[('false', fm.GAUSSIAN, [0, 0.4]),
                        ('true', fm.GAUSSIAN, [1, 0.4])]
    )
    fuzzy_vars.add(
        var_name='comp4',
        var_type='consequent',
        var_range=np.arange(0, 1+1e-5, 0.1),
        membership_funcs=[('false', fm.GAUSSIAN, [0, 0.4]),
                        ('true', fm.GAUSSIAN, [1, 0.4])]
    )

    fuzzy_rule = FuzzyRules()
    fuzzy_rule.add(
        'rule1',
        if_term=fuzzy_vars.get('volt')['high']&fuzzy_vars.get('rotate')['high']&fuzzy_vars.get('vibration')['low'],
        then_term=fuzzy_vars.get('comp1')['true']
    )
    fuzzy_rule.add(
        'rule2',
        if_term=fuzzy_vars.get('rotate')['low']&fuzzy_vars.get('volt')['low']&fuzzy_vars.get('vibration')['low'],
        then_term=fuzzy_vars.get('comp2')['true']
    )
    fuzzy_rule.add(
        'rule3',
        if_term=fuzzy_vars.get('vibration')['high']&fuzzy_vars.get('volt')['low']&fuzzy_vars.get('rotate')['high'],
        then_term=fuzzy_vars.get('comp4')['true']
    )
    fuzzy_rule.add(
        'rule4',
        if_term=fuzzy_vars.get('volt')['low'],
        then_term=fuzzy_vars.get('comp1')['false']
    )
    fuzzy_rule.add(
        'rule5',
        if_term=fuzzy_vars.get('rotate')['high'],
        then_term=fuzzy_vars.get('comp2')['false']
    )
    fuzzy_rule.add(
        'rule6',
        if_term=fuzzy_vars.get('vibration')['low'],
        then_term=fuzzy_vars.get('comp4')['false']
    )

    class CustomFuzzyModel(FuzzyModel):
        def process_rules_pointwise(self, input_data: dict) -> dict:
            if self.rule_engine is None:
                raise ValueError(
                    (
                        "Property rule_engine is None. Please load your rule_engine "
                        "to run this method."
                    )
                )

            input_data = np.array(list(input_data.values()))
            daily_average = np.average(
                input_data.reshape((-1, 4)), axis=0
            )
            input_data = {
                "volt": daily_average[0],
                "rotate": daily_average[1],
                "vibration": daily_average[3]
            } 
            for key, value in input_data.items():
                self.rule_engine.input[key] = value
            self.rule_engine.compute()

            outputs = {}
            for cls in self.rule_engine.ctrl.consequents:
                outputs[cls.label] = round(self.rule_engine.output[cls.label], 5)
            return outputs

    modeler = FuzzyModeler(model_class=CustomFuzzyModel)
    teacher = modeler.build_model(fuzzy_vars, fuzzy_rule)
    return teacher

# %%
# you can download the data from kaggle using the following link.
# https://www.kaggle.com/datasets/arnabbiswas1/microsoft-azure-predictive-maintenance

dir_path = '/Users/aitomatic/Desktop/dataset/azure_iot'
path = f'{dir_path}/'
telemetry_url = 'PdM_telemetry.csv'
df = pd.read_csv(path + 'PdM_telemetry.csv')
df.loc[:, 'datetime'] = pd.to_datetime(df['datetime'])
df.loc[:, 'datetime'] = df['datetime'] - pd.Timedelta(hours=6)
df_machines = pd.read_csv(path + 'PdM_machines.csv')
df = df.join(df_machines.set_index('machineID'), on='machineID')
df.loc[:, 'date'] = df['datetime'].dt.date
df_failures = pd.read_csv(path + 'PdM_failures.csv')
df_failures.shape
# Out:
# (761, 3)

# %%
for model_type in ['model1', 'model2', 'model3', 'model4']:
    id_list = df[df.model == model_type].machineID.unique()
    print(f'{model_type} failure records:', df_failures[df_failures.machineID.isin(id_list)].shape)
# Out:
# model1 failure records: (189, 3)
# model2 failure records: (168, 3)
# model3 failure records: (221, 3)
# model4 failure records: (183, 3)

# %%
import datetime

df_model3 = df[df.model=='model3']
df_model3 = df_model3[df_model3.date != datetime.datetime(2016, 1, 1).date()]
df_model3.shape
# Out:
# (306600, 9)

# %%
from datetime import timedelta

df_model3_failures = df_failures[df_failures.machineID.isin(df_model3.machineID.unique())]
df_model3_failures.shape


df_model3_failures['datetime'] = pd.to_datetime(df_model3_failures['datetime'])
df_model3_failures['date'] = df_model3_failures['datetime'].apply(lambda x: x.date())
df_model3_failures['date_1'] = df_model3_failures['date'] - timedelta(days=1)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_model3_failures.failure.value_counts()
# Out:
# comp2    89
# comp1    68
# comp4    64
# Name: failure, dtype: int64

# %%
df_model3_daily = df_model3.groupby(['date', 'machineID']).agg('mean')

# %%
# We will use these values as threshold value of boolean rule (98 percentile)
percentile = 0.96
print('volt:', df_model3_daily['volt'].quantile(percentile))
print('rotate:', df_model3_daily['rotate'].quantile(1-percentile))
print('vibration:', df_model3_daily['vibration'].quantile(percentile))
# Out:
# volt: 178.994274651537
# rotate: 405.58135851278706
# vibration: 43.93598497211916

# %%
df_model3.machineID.nunique()
# Out:
# 35

# %%
keys = ['machineID', 'date']
features = ['volt', 'rotate', 'pressure', 'vibration']

# %%
column_values = []
for idx in range(24):
    column_values.extend([f'{feature}_{idx}' for feature in features])
print(column_values)
# Out:
# ['volt_0', 'rotate_0', 'pressure_0', 'vibration_0', 'volt_1', 'rotate_1', 'pressure_1', 'vibration_1', 'volt_2', 'rotate_2', 'pressure_2', 'vibration_2', 'volt_3', 'rotate_3', 'pressure_3', 'vibration_3', 'volt_4', 'rotate_4', 'pressure_4', 'vibration_4', 'volt_5', 'rotate_5', 'pressure_5', 'vibration_5', 'volt_6', 'rotate_6', 'pressure_6', 'vibration_6', 'volt_7', 'rotate_7', 'pressure_7', 'vibration_7', 'volt_8', 'rotate_8', 'pressure_8', 'vibration_8', 'volt_9', 'rotate_9', 'pressure_9', 'vibration_9', 'volt_10', 'rotate_10', 'pressure_10', 'vibration_10', 'volt_11', 'rotate_11', 'pressure_11', 'vibration_11', 'volt_12', 'rotate_12', 'pressure_12', 'vibration_12', 'volt_13', 'rotate_13', 'pressure_13', 'vibration_13', 'volt_14', 'rotate_14', 'pressure_14', 'vibration_14', 'volt_15', 'rotate_15', 'pressure_15', 'vibration_15', 'volt_16', 'rotate_16', 'pressure_16', 'vibration_16', 'volt_17', 'rotate_17', 'pressure_17', 'vibration_17', 'volt_18', 'rotate_18', 'pressure_18', 'vibration_18', 'volt_19', 'rotate_19', 'pressure_19', 'vibration_19', 'volt_20', 'rotate_20', 'pressure_20', 'vibration_20', 'volt_21', 'rotate_21', 'pressure_21', 'vibration_21', 'volt_22', 'rotate_22', 'pressure_22', 'vibration_22', 'volt_23', 'rotate_23', 'pressure_23', 'vibration_23']

# %%
def preprocess_data(list_of_daily_data, features):
    x_train_list = []
    y_train_list = []
    for idx, df_daily_one in list_of_daily_data:
        mid = idx[0]
        date = idx[1]

        if df_daily_one.shape[0] != 24:
            continue

        df_filtered_f = df_model3_failures[
            (df_model3_failures.date_1==date)&(df_model3_failures.machineID==mid)]
        y_label = {"comp1": 0, "comp2": 0, "comp4": 0}
        if df_filtered_f.shape[0] >= 1:
            for i in range(df_filtered_f.shape[0]):
                y_label.update({df_filtered_f['failure'].iloc[i]: 1})
        x_train_list.append(np.concatenate(df_daily_one[features].values).tolist())
        y_train_list.append(y_label)
    return x_train_list, y_train_list

# %%
from sklearn.utils import resample

def handle_data_imbalance(df_x, df_y):
    df_train_y_normal = df_y[df_y.sum(axis=1) == 0]
    df_train_y_normal_resampled = resample(df_train_y_normal,
                replace=True,
                n_samples=100,
                random_state=42)
    df_train_x_normal_resampled = df_x.filter(items = df_train_y_normal_resampled.index, axis=0)
    assert all(df_train_y_normal_resampled.head().index == df_train_x_normal_resampled.head().index)

    df_train_y_abnormal = df_y[df_y.sum(axis=1) != 0]
    df_train_y_abnormal_resampled = resample(df_train_y_abnormal,
                replace=True,
                n_samples=600,
                random_state=42)
    df_train_y_abnormal_resampled.shape
    df_train_x_abnormal_resampled = df_x.filter(items = df_train_y_abnormal_resampled.index, axis=0)
    df_train_x_abnormal_resampled.shape
    assert all(df_train_y_abnormal_resampled.head().index == df_train_x_abnormal_resampled.head().index)

    df_train_y_final = pd.concat([df_train_y_normal_resampled, df_train_y_abnormal_resampled], axis=0)
    df_train_x_final = pd.concat([df_train_x_normal_resampled, df_train_x_abnormal_resampled], axis=0)

    return df_train_x_final, df_train_y_final

# %%
from collections import defaultdict
from sklearn.model_selection import KFold
from h1st.model.oracle import OracleModeler
from h1st.model.oracle.ensemble import GradBoostEnsembleModeler

# prepare cross validation
kfold = KFold(n_splits=5, shuffle=True, random_state=3)

all_metrics = defaultdict(lambda: defaultdict(list))
all_index = defaultdict(lambda: defaultdict(list))

# 1. build rule-based model
bool_teacher = RuleModel()
fuzzy_teacher = create_fuzzy_model(df_model3_daily)

for no, m_ids in enumerate(kfold.split(df_model3.machineID.unique())):
    train_id, test_id = m_ids
    df_train = df_model3[df_model3.machineID.isin(train_id)]
    df_test = df_model3[df_model3.machineID.isin(test_id)]

    temp_gb = df_train.groupby(keys)
    list_of_train_daily = [item for item in temp_gb]

    temp_gb = df_test.groupby(keys)
    list_of_test_daily = [item for item in temp_gb]

    # print(len(train_id), len(test_id),df_train.shape, df_test.shape)
    # print(f'number of data points in train dataset: {len(list_of_train_daily)}')
    # print(f'number of data points in test dataset: {len(list_of_test_daily)}')

    
    x_train_list, y_train_list = preprocess_data(list_of_train_daily, features)
    x_test_list, y_test_list = preprocess_data(list_of_test_daily, features)

    df_train_x = pd.DataFrame(x_train_list, columns=column_values)
    df_train_y = pd.DataFrame(y_train_list)
    df_test_x = pd.DataFrame(x_test_list, columns=column_values)
    df_test_y = pd.DataFrame(y_test_list)

    df_train_x_final, df_train_y_final = handle_data_imbalance(df_train_x, df_train_y)
    # print(df_train_x.shape, df_train_y.shape, df_test_x.shape, df_test_y.shape)
    # print(no, df_train_x_final.shape, df_train_y_final.shape)   
    input_data = {
        "unlabeled_data": df_train_x_final,
        "labeled_data": {
            "x_train": df_train_x_final.reset_index(drop=True),
            "y_train": df_train_y_final.reset_index(drop=True),
            "x_test": df_test_x,
            "y_test": df_test_y,
        },
    }

    # 3. build oracle
    # 3.1 bool
    modeler = OracleModeler()
    oracle_with_bool = modeler.build_model(
        data=input_data,
        teacher=bool_teacher)

    # 3.2 fuzzy
    fuzzy_thresholds = {'comp1': 0.6, 'comp2': 0.6, 'comp4': 0.6}
    oracle_with_fuzzy = modeler.build_model(
        data=input_data,
        teacher=fuzzy_teacher,
        fuzzy_thresholds=fuzzy_thresholds)

    # 3.3 bool + ml_ensemble
    oracle_with_bool_ml = modeler.build_model(
        data=input_data, 
        teacher=bool_teacher,
        ensembler_modeler=GradBoostEnsembleModeler())

    # 3.4 fuzzy + ml_ensemble
    fuzzy_thresholds = {'comp1': 0.6, 'comp2': 0.6, 'comp4': 0.6}
    oracle_with_fuzzy_ml = modeler.build_model(
        data=input_data, 
        teacher=fuzzy_teacher,
        fuzzy_thresholds=fuzzy_thresholds,
        ensembler_modeler=GradBoostEnsembleModeler()) 

    # 3.5 bool + ml_ensemble + x
    oracle_with_bool_ml_x = modeler.build_model(
        data=input_data, 
        teacher=bool_teacher,
        ensembler_modeler=GradBoostEnsembleModeler(),
        inject_x_in_ensembler=True)

    # 3.6 fuzzy + ml_ensemble + x
    fuzzy_thresholds = {'comp1': 0.6, 'comp2': 0.6, 'comp4': 0.6}
    oracle_with_fuzzy_ml_x = modeler.build_model(
        data=input_data, 
        teacher=fuzzy_teacher,
        fuzzy_thresholds=fuzzy_thresholds,
        ensembler_modeler=GradBoostEnsembleModeler(),
        inject_x_in_ensembler=True) 

    model_map = {
        "oracle_with_bool": oracle_with_bool,
        "oracle_with_fuzzy": oracle_with_fuzzy,
        "oracle_with_bool_ml": oracle_with_bool_ml,
        "oracle_with_fuzzy_ml": oracle_with_fuzzy_ml,
        "oracle_with_bool_ml_x": oracle_with_bool_ml_x,
        "oracle_with_fuzzy_ml_x": oracle_with_fuzzy_ml_x,        
    }

    # 4. collect evaluation results
    for name, oracle in model_map.items():
        for metrics in ['f1_score', 'precision', 'recall']:
            for label in ['comp1', 'comp2', 'comp4']:
                temp = oracle.metrics[metrics][label]
                s1, s2 = temp.pop('students')
                temp.update({'student1': s1, 'student2': s2})
                all_metrics[metrics][name].append({label: temp})
                # all_index[metrics][name].append(f'{label}_{name}_{no}')
# Out:
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.
# INFO:root:Evaluated all sub models successfully.

# %%
all_metrics['f1_score']['oracle_with_bool']
# Out:
# [{'comp1': {'teacher': 0.15385,
#    'ensemblers': 0.17391,
#    'student1': 0.0,
#    'student2': 0.12903}},
#  {'comp2': {'teacher': 0.37037,
#    'ensemblers': 0.38095,
#    'student1': 0.2,
#    'student2': 0.44444}},
#  {'comp4': {'teacher': 0.375,
#    'ensemblers': 0.34286,
#    'student1': 0.25,
#    'student2': 0.31579}},
#  {'comp1': {'teacher': 0.23256,
#    'ensemblers': 0.15385,
#    'student1': 0.11111,
#    'student2': 0.22642}},
#  {'comp2': {'teacher': 0.22727,
#    'ensemblers': 0.07143,
#    'student1': 0.0,
#    'student2': 0.18182}},
#  {'comp4': {'teacher': 0.35294,
#    'ensemblers': 0.33333,
#    'student1': 0.30769,
#    'student2': 0.28571}},
#  {'comp1': {'teacher': 0.4,
#    'ensemblers': 0.28571,
#    'student1': 0.16667,
#    'student2': 0.29412}},
#  {'comp2': {'teacher': 0.26667,
#    'ensemblers': 0.11111,
#    'student1': 0.0,
#    'student2': 0.21053}},
#  {'comp4': {'teacher': 0.19048,
#    'ensemblers': 0.19048,
#    'student1': 0.1,
#    'student2': 0.16667}},
#  {'comp1': {'teacher': 0.11765,
#    'ensemblers': 0.125,
#    'student1': 0.0,
#    'student2': 0.15385}},
#  {'comp2': {'teacher': 0.21429,
#    'ensemblers': 0.27273,
#    'student1': 0.16667,
#    'student2': 0.21429}},
#  {'comp4': {'teacher': 0.17647,
#    'ensemblers': 0.16216,
#    'student1': 0.16667,
#    'student2': 0.19512}},
#  {'comp1': {'teacher': 0.08,
#    'ensemblers': 0.1,
#    'student1': 0.22222,
#    'student2': 0.08696}},
#  {'comp2': {'teacher': 0.15385,
#    'ensemblers': 0.18182,
#    'student1': 0.13333,
#    'student2': 0.24}},
#  {'comp4': {'teacher': 0.3871,
#    'ensemblers': 0.35294,
#    'student1': 0.375,
#    'student2': 0.23529}}]

# %%
all_avg_metrics = []
oracle_names = []
for metrics_type in ['f1_score', 'precision', 'recall']:
    for oracle_name, metrics in all_metrics[metrics_type].items():

        temp = defaultdict(list)
        for m in metrics:
            for label, met in m.items():
                temp[label].append(met)

        for label in temp:
            df_metrics = pd.DataFrame(temp[label])
            # print(metrics_type, oracle_name, df_metrics.mean().values)
            all_avg_metrics.append(
                [metrics_type, label] + list(df_metrics.mean().values)
            )
            oracle_names.append(f'{label}_{oracle_name}')

final_metrics = pd.DataFrame(
    all_avg_metrics,
    columns=['metrics_type', 'label', 'teacher', 'ensemblers', 'student1', 'student2'],
    index=oracle_names
)

# %%
final_metrics[final_metrics.label=='comp1']
# Out:
#                              metrics_type  label   teacher  ensemblers  \
# comp1_oracle_with_bool           f1_score  comp1  0.196812    0.167694
# comp1_oracle_with_fuzzy          f1_score  comp1  0.215880    0.173052
# comp1_oracle_with_bool_ml        f1_score  comp1  0.196812    0.017392
# comp1_oracle_with_fuzzy_ml       f1_score  comp1  0.215880    0.111484
# comp1_oracle_with_bool_ml_x      f1_score  comp1  0.196812    0.116020
# comp1_oracle_with_fuzzy_ml_x     f1_score  comp1  0.215880    0.226374
# comp1_oracle_with_bool          precision  comp1  0.123628    0.108962
# comp1_oracle_with_fuzzy         precision  comp1  0.127868    0.123214
# comp1_oracle_with_bool_ml       precision  comp1  0.123628    0.010000
# comp1_oracle_with_fuzzy_ml      precision  comp1  0.127868    0.067752
# comp1_oracle_with_bool_ml_x     precision  comp1  0.123628    0.064042
# comp1_oracle_with_fuzzy_ml_x    precision  comp1  0.127868    0.133638
# comp1_oracle_with_bool             recall  comp1  0.521666    0.406666
# comp1_oracle_with_fuzzy            recall  comp1  0.803334    0.345000
# comp1_oracle_with_bool_ml          recall  comp1  0.521666    0.066666
# comp1_oracle_with_fuzzy_ml         recall  comp1  0.803334    0.380000
# comp1_oracle_with_bool_ml_x        recall  comp1  0.521666    0.808334
# comp1_oracle_with_fuzzy_ml_x       recall  comp1  0.803334    0.910000
#
#                               student1  student2
# comp1_oracle_with_bool        0.100000  0.178076
# comp1_oracle_with_fuzzy       0.173052  0.185066
# comp1_oracle_with_bool_ml     0.187134  0.178076
# comp1_oracle_with_fuzzy_ml    0.160132  0.185066
# comp1_oracle_with_bool_ml_x   0.160172  0.178076
# comp1_oracle_with_fuzzy_ml_x  0.152086  0.185066
# comp1_oracle_with_bool        0.108334  0.108418
# comp1_oracle_with_fuzzy       0.123214  0.105834
# comp1_oracle_with_bool_ml     0.203174  0.108418
# comp1_oracle_with_fuzzy_ml    0.112206  0.105834
# comp1_oracle_with_bool_ml_x   0.173332  0.108418
# comp1_oracle_with_fuzzy_ml_x  0.097558  0.105834
# comp1_oracle_with_bool        0.111666  0.591666
# comp1_oracle_with_fuzzy       0.345000  0.880000
# comp1_oracle_with_bool_ml     0.261666  0.591666
# comp1_oracle_with_fuzzy_ml    0.340000  0.880000
# comp1_oracle_with_bool_ml_x   0.191666  0.591666
# comp1_oracle_with_fuzzy_ml_x  0.370000  0.880000

# %%
final_metrics[final_metrics.label=='comp2']
# Out:
#                              metrics_type  label   teacher  ensemblers  \
# comp2_oracle_with_bool           f1_score  comp2  0.246490    0.203608
# comp2_oracle_with_fuzzy          f1_score  comp2  0.296784    0.288412
# comp2_oracle_with_bool_ml        f1_score  comp2  0.246490    0.168374
# comp2_oracle_with_fuzzy_ml       f1_score  comp2  0.296784    0.032000
# comp2_oracle_with_bool_ml_x      f1_score  comp2  0.246490    0.211672
# comp2_oracle_with_fuzzy_ml_x     f1_score  comp2  0.296784    0.278160
# comp2_oracle_with_bool          precision  comp2  0.172528    0.165652
# comp2_oracle_with_fuzzy         precision  comp2  0.181622    0.182302
# comp2_oracle_with_bool_ml       precision  comp2  0.172528    0.108618
# comp2_oracle_with_fuzzy_ml      precision  comp2  0.181622    0.025000
# comp2_oracle_with_bool_ml_x     precision  comp2  0.172528    0.119806
# comp2_oracle_with_fuzzy_ml_x    precision  comp2  0.181622    0.164352
# comp2_oracle_with_bool             recall  comp2  0.443290    0.281672
# comp2_oracle_with_fuzzy            recall  comp2  0.820636    0.717606
# comp2_oracle_with_bool_ml          recall  comp2  0.443290    0.512986
# comp2_oracle_with_fuzzy_ml         recall  comp2  0.820636    0.044444
# comp2_oracle_with_bool_ml_x        recall  comp2  0.443290    0.926984
# comp2_oracle_with_fuzzy_ml_x       recall  comp2  0.820636    0.920636
#
#                               student1  student2
# comp2_oracle_with_bool        0.100000  0.258216
# comp2_oracle_with_fuzzy       0.295924  0.261526
# comp2_oracle_with_bool_ml     0.110714  0.258216
# comp2_oracle_with_fuzzy_ml    0.268500  0.261526
# comp2_oracle_with_bool_ml_x   0.084342  0.258216
# comp2_oracle_with_fuzzy_ml_x  0.272560  0.261526
# comp2_oracle_with_bool        0.262222  0.194088
# comp2_oracle_with_fuzzy       0.186688  0.154798
# comp2_oracle_with_bool_ml     0.145000  0.194088
# comp2_oracle_with_fuzzy_ml    0.171454  0.154798
# comp2_oracle_with_bool_ml_x   0.160000  0.194088
# comp2_oracle_with_fuzzy_ml_x  0.171666  0.154798
# comp2_oracle_with_bool        0.084128  0.418038
# comp2_oracle_with_fuzzy       0.739828  0.876192
# comp2_oracle_with_bool_ml     0.095960  0.418038
# comp2_oracle_with_fuzzy_ml    0.648630  0.876192
# comp2_oracle_with_bool_ml_x   0.073738  0.418038
# comp2_oracle_with_fuzzy_ml_x  0.689034  0.876192

# %%
final_metrics[final_metrics.label=='comp4']
# Out:
#                              metrics_type  label   teacher  ensemblers  \
# comp4_oracle_with_bool           f1_score  comp4  0.296398    0.276354
# comp4_oracle_with_fuzzy          f1_score  comp4  0.236982    0.225270
# comp4_oracle_with_bool_ml        f1_score  comp4  0.296398    0.059762
# comp4_oracle_with_fuzzy_ml       f1_score  comp4  0.236982    0.241270
# comp4_oracle_with_bool_ml_x      f1_score  comp4  0.296398    0.184710
# comp4_oracle_with_fuzzy_ml_x     f1_score  comp4  0.236982    0.235496
# comp4_oracle_with_bool          precision  comp4  0.188550    0.170592
# comp4_oracle_with_fuzzy         precision  comp4  0.144910    0.147764
# comp4_oracle_with_bool_ml       precision  comp4  0.188550    0.038888
# comp4_oracle_with_fuzzy_ml      precision  comp4  0.144910    0.183616
# comp4_oracle_with_bool_ml_x     precision  comp4  0.188550    0.106050
# comp4_oracle_with_fuzzy_ml_x    precision  comp4  0.144910    0.137450
# comp4_oracle_with_bool             recall  comp4  0.754762    0.779762
# comp4_oracle_with_fuzzy            recall  comp4  0.694048    0.551192
# comp4_oracle_with_bool_ml          recall  comp4  0.754762    0.178572
# comp4_oracle_with_fuzzy_ml         recall  comp4  0.694048    0.573808
# comp4_oracle_with_bool_ml_x        recall  comp4  0.754762    0.767858
# comp4_oracle_with_fuzzy_ml_x       recall  comp4  0.694048    0.917858
#
#                               student1  student2
# comp4_oracle_with_bool        0.239872  0.239716
# comp4_oracle_with_fuzzy       0.240902  0.213838
# comp4_oracle_with_bool_ml     0.265462  0.239716
# comp4_oracle_with_fuzzy_ml    0.215350  0.213838
# comp4_oracle_with_bool_ml_x   0.253918  0.239716
# comp4_oracle_with_fuzzy_ml_x  0.215466  0.213838
# comp4_oracle_with_bool        0.151224  0.144296
# comp4_oracle_with_fuzzy       0.158282  0.126460
# comp4_oracle_with_bool_ml     0.165158  0.144296
# comp4_oracle_with_fuzzy_ml    0.140390  0.126460
# comp4_oracle_with_bool_ml_x   0.156114  0.144296
# comp4_oracle_with_fuzzy_ml_x  0.141032  0.126460
# comp4_oracle_with_bool        0.630952  0.779762
# comp4_oracle_with_fuzzy       0.604762  0.754762
# comp4_oracle_with_bool_ml     0.729762  0.779762
# comp4_oracle_with_fuzzy_ml    0.509524  0.754762
# comp4_oracle_with_bool_ml_x   0.754762  0.779762
# comp4_oracle_with_fuzzy_ml_x  0.509524  0.754762
