# %%
import h1st as h1
h1.init()

# %%
from wine_quality import WineQuality

# %%
# Instantiate the WineQuality
model = WineQuality()

# %%
# Load the Wine Quality dataset
data = model.load_data()

# %%
# Explore the Wine Quality Rating Labels
# model.explore_data()

# %%
# Prepare the data
prepared_data = model.prep_data(data)

# %%
# Train the RandomForestRegressor Model
model.train(prepared_data)

# %%
# Compute the Metrics: MAE for the RandomForestRegressor Model
model.evaluate(prepared_data)
# Out:
# {'mape': 8.488804951670085}

# %%
describer = model.describe()

# %%
describer.shap_describer.shap_values.shape
# Out:
# (1279, 11)

# %%
# old
pred_dict = model.explain('data_scientist', decision=sample_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c48dd0ed248d> in <module>
#       1 # old
# ----> 2 pred_dict = model.explain('data_scientist', decision=sample_input)
#
# NameError: name 'sample_input' is not defined

# %%
# Describe the Global Feature Importance for the Wine Quality Dataset
s =m.describe('data_scientist')
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#                                        DATA SCIENTIST VIEW!
#
#
#       Training Data
#          Number of row:1279 ; features:11
#
#
#       Model Details
#          Model Type:RandomForestRegressor
#          Model Metrics:{'mae': 0.5338125466472187}
#
#
# The plot below shows SHAP values of every feature for every sample.
# The SHAP values show the distribution of the impacts each feature has on the model output.
# The color represents the feature value (red high, blue low).
# For example, high alcohol increases the predicted wine quality.
# Dependence plots for the 3 most Impactful Features
